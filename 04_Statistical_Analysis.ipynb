# %% [markdown]
# # Statistical Analysis
#
# In this notebook, we will perform a comprehensive statistical analysis of our dataset. The objective is to understand the relationships between the different features and their impact on income, the target variable. By doing this, we can gain deeper insights that will aid in the creation and tuning of our machine learning models in the following steps.
#
# Let's begin by importing the necessary libraries and loading our dataset.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
from scipy.stats import chi2_contingency
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('adult_data_preprocessed.csv')

# %% [markdown]
# ## Hypothesis Testing for Numerical Variables
#
# Before we can perform certain statistical tests, we need to check the normality of our variables. A common assumption in many statistical techniques is that the data follows a normal distribution. We can test this assumption using the Shapiro-Wilk test.
#
# The null hypothesis for the Shapiro-Wilk test is that the data is drawn from a normal distribution. If the p-value is less than our chosen significance level (commonly 0.05), we reject the null hypothesis and conclude that the data does not come from a normal distribution. On the other hand, if the p-value is greater than our significance level, we fail to reject the null hypothesis and conclude that the data does come from a normal distribution.

# %%
# Define numerical variables
numerical_vars = ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']

# Perform Shapiro-Wilk test
for var in numerical_vars:
    stat, p = stats.shapiro(df[var])
    print(f'Shapiro-Wilk Test for {var}:\nStatistic={stat}, p-value={p}\n')
# Out:
# Shapiro-Wilk Test for age:
# Statistic=0.9668066501617432, p-value=0.0
#
# Shapiro-Wilk Test for fnlwgt:
# Statistic=0.9223408699035645, p-value=0.0
#
# Shapiro-Wilk Test for education-num:
# Statistic=0.9264371395111084, p-value=0.0
#
# Shapiro-Wilk Test for capital-gain:
# Statistic=0.12271404266357422, p-value=0.0
#
# Shapiro-Wilk Test for capital-loss:
# Statistic=0.21831119060516357, p-value=0.0
#
# Shapiro-Wilk Test for hours-per-week:
# Statistic=0.8851711750030518, p-value=0.0

# %% [markdown]
# The p-values for all our numerical variables are less than the commonly used significance level of 0.05. Therefore, we reject the null hypothesis for each variable, concluding that the data for these variables do not come from a normal distribution.
#
# This is important information to consider as we move forward with our statistical analysis. Many statistical tests assume normality, so we may need to use non-parametric tests or apply transformations to our data if we want to use tests that assume normality.

# %% [markdown]
# ## T-tests for Numerical Variables

# %%
# Perform t-tests
for var in numerical_vars:
    less_than_50k = df[df['income'] == '<=50K'][var]
    more_than_50k = df[df['income'] == '>50K'][var]

    t_stat, p_val = stats.ttest_ind(less_than_50k, more_than_50k)

    print(f'T-Test for {var}:\nT-Statistic={t_stat}, p-value={p_val}\n')
# Out:
# T-Test for age:
# T-Statistic=-43.43624424045112, p-value=0.0
#
# T-Test for fnlwgt:
# T-Statistic=1.7075109328052842, p-value=0.08773666108063974
#
# T-Test for education-num:
# T-Statistic=-64.18797223551665, p-value=0.0
#
# T-Test for capital-gain:
# T-Statistic=-41.341868169493665, p-value=0.0
#
# T-Test for capital-loss:
# T-Statistic=-27.47417790492585, p-value=2.68654718905867e-164
#
# T-Test for hours-per-week:
# T-Statistic=-42.58387349943796, p-value=0.0

# %% [markdown]
# The T-test is a statistical hypothesis test that assumes (the null hypothesis) that the means of two populations are equal.
#
# For each numerical variable, we performed a T-test with respect to the 'income' classes. The results include a statistic and a p-value.
#
# A small p-value (typically ≤ 0.05) indicates strong evidence that the null hypothesis is incorrect, i.e., the means of the two populations are significantly different, which suggests the variable likely has a significant relationship with the target variable.
#
# On the other hand, a large p-value (> 0.05) indicates weak evidence against the null hypothesis, so you fail to reject the null hypothesis. This means the variable likely does not have a significant relationship with the target variable.

# %% [markdown]
# ## Chi-Square Tests for Categorical Variables

# %%
# Get list of all categorical columns (one-hot encoded)
categorical_cols = [col for col in df.columns if col not in numerical_vars + ['income']]

# Perform Chi-Square tests
for var in categorical_cols:
    contingency_table = pd.crosstab(df[var], df['income'])
    chi2, p_val, dof, expected = chi2_contingency(contingency_table)

    print(f'Chi-Square Test for {var}:\nChi2={chi2}, p-value={p_val}\n')
# Out:
# Chi-Square Test for workclass_Federal-gov:
# Chi2=113.95824874066832, p-value=1.3308131398791266e-26
#
# Chi-Square Test for workclass_Local-gov:
# Chi2=35.338974038055184, p-value=2.770324658615066e-09
#
# Chi-Square Test for workclass_Never-worked:
# Chi2=1.0987433937485032, p-value=0.2945420423054194
#
# Chi-Square Test for workclass_Private:
# Chi2=512.7610556998344, p-value=1.5903442762392623e-113
#
# Chi-Square Test for workclass_Self-emp-inc:
# Chi2=631.5498295777486, p-value=2.3001082226580175e-139
#
# Chi-Square Test for workclass_Self-emp-not-inc:
# Chi2=29.080977641768094, p-value=6.941522115796686e-08
#
# Chi-Square Test for workclass_State-gov:
# Chi2=6.997598758358855, p-value=0.008161912774929033
#
# Chi-Square Test for workclass_Without-pay:
# Chi2=3.222564739783703, p-value=0.0726297502727671
#
# Chi-Square Test for education_10th:
# Chi2=158.74111273523948, p-value=2.131604526551785e-36
#
# Chi-Square Test for education_11th:
# Chi2=238.9841334949431, p-value=6.54955335358297e-54
#
# Chi-Square Test for education_12th:
# Chi2=64.12194599471827, p-value=1.1695151388016874e-15
#
# Chi-Square Test for education_1st-4th:
# Chi2=37.735145095818396, p-value=8.103142795323117e-10
#
# Chi-Square Test for education_5th-6th:
# Chi2=67.31820075813788, p-value=2.3103860633011406e-16
#
# Chi-Square Test for education_7th-8th:
# Chi2=114.37131289996319, p-value=1.080559945299545e-26
#
# Chi-Square Test for education_9th:
# Chi2=100.2212638050964, p-value=1.3628842400997188e-23
#
# Chi-Square Test for education_Assoc-acdm:
# Chi2=0.3026134190525534, p-value=0.5822486615419316
#
# Chi-Square Test for education_Assoc-voc:
# Chi2=3.171757388382362, p-value=0.07492178962801133
#
# Chi-Square Test for education_Bachelors:
# Chi2=1059.5358436509098, p-value=2.059150871917246e-232
#
# Chi-Square Test for education_Doctorate:
# Chi2=569.5032193012106, p-value=7.200786253756046e-126
#
# Chi-Square Test for education_HS-grad:
# Chi2=559.7327442083508, p-value=9.610725399713117e-124
#
# Chi-Square Test for education_Masters:
# Chi2=990.4599995251588, p-value=2.127786479330355e-217
#
# Chi-Square Test for education_Preschool:
# Chi2=14.909793905463253, p-value=0.00011277597638688729
#
# Chi-Square Test for education_Prof-school:
# Chi2=778.5919856002556, p-value=2.435721232405054e-171
#
# Chi-Square Test for education_Some-college:
# Chi2=131.08370978539375, p-value=2.37381903620803e-30
#
# Chi-Square Test for marital-status_Divorced:
# Chi2=524.270091438161, p-value=4.983496815042894e-116
#
# Chi-Square Test for marital-status_Married-AF-spouse:
# Chi2=3.7346305042676144, p-value=0.0532954531179647
#
# Chi-Square Test for marital-status_Married-civ-spouse:
# Chi2=6437.003194165887, p-value=0.0
#
# Chi-Square Test for marital-status_Married-spouse-absent:
# Chi2=58.02037268780761, p-value=2.5941720722485644e-14
#
# Chi-Square Test for marital-status_Never-married:
# Chi2=3300.237450775571, p-value=0.0
#
# Chi-Square Test for marital-status_Separated:
# Chi2=179.17515750137198, p-value=7.337010405992926e-41
#
# Chi-Square Test for marital-status_Widowed:
# Chi2=134.0894116349137, p-value=5.2229572877234e-31
#
# Chi-Square Test for occupation_Adm-clerical:
# Chi2=263.00212420890864, p-value=3.803110205282235e-59
#
# Chi-Square Test for occupation_Armed-Forces:
# Chi2=0.27069307459193165, p-value=0.6028672305534155
#
# Chi-Square Test for occupation_Craft-repair:
# Chi2=5.061144912893932, p-value=0.02446806861970721
#
# Chi-Square Test for occupation_Exec-managerial:
# Chi2=1501.6713575778526, p-value=0.0
#
# Chi-Square Test for occupation_Farming-fishing:
# Chi2=87.0860713370686, p-value=1.0389970017574696e-20
#
# Chi-Square Test for occupation_Handlers-cleaners:
# Chi2=246.94316803923152, p-value=1.2046828259797816e-55
#
# Chi-Square Test for occupation_Machine-op-inspct:
# Chi2=156.1528567669883, p-value=7.839079128909621e-36
#
# Chi-Square Test for occupation_Other-service:
# Chi2=794.7291264546532, p-value=7.551767712273146e-175
#
# Chi-Square Test for occupation_Priv-house-serv:
# Chi2=43.59219072110936, p-value=4.0444978817449985e-11
#
# Chi-Square Test for occupation_Prof-specialty:
# Chi2=415.04057041786143, p-value=2.9304875150493796e-92
#
# Chi-Square Test for occupation_Protective-serv:
# Chi2=25.275923580837503, p-value=4.96872379348948e-07
#
# Chi-Square Test for occupation_Sales:
# Chi2=18.095747877001607, p-value=2.100700273990806e-05
#
# Chi-Square Test for occupation_Tech-support:
# Chi2=21.14033252392265, p-value=4.268491036198815e-06
#
# Chi-Square Test for occupation_Transport-moving:
# Chi2=14.786301975895306, p-value=0.00012040696029281319
#
# Chi-Square Test for relationship_Husband:
# Chi2=5234.851915880949, p-value=0.0
#
# Chi-Square Test for relationship_Not-in-family:
# Chi2=1155.9221718617378, p-value=2.3162769555736818e-253
#
# Chi-Square Test for relationship_Other-relative:
# Chi2=227.05823930603773, p-value=2.6116149316303626e-51
#
# Chi-Square Test for relationship_Own-child:
# Chi2=1699.0846951446654, p-value=0.0
#
# Chi-Square Test for relationship_Unmarried:
# Chi2=663.4256454811895, p-value=2.687467774689085e-146
#
# Chi-Square Test for relationship_Wife:
# Chi2=493.38297375186437, p-value=2.6164996308470546e-109
#
# Chi-Square Test for race_Amer-Indian-Eskimo:
# Chi2=26.173361187916797, p-value=3.120983823792378e-07
#
# Chi-Square Test for race_Asian-Pac-Islander:
# Chi2=3.4805366461486407, p-value=0.06209459964927518
#
# Chi-Square Test for race_Black:
# Chi2=257.72248740435316, p-value=5.382298136809789e-58
#
# Chi-Square Test for race_Other:
# Chi2=32.17476426303148, p-value=1.4090913739500128e-08
#
# Chi-Square Test for race_White:
# Chi2=235.93296330815826, p-value=3.0306241086552862e-53
#
# Chi-Square Test for sex_Female:
# Chi2=1517.8134091344452, p-value=0.0
#
# Chi-Square Test for sex_Male:
# Chi2=1517.813409134445, p-value=0.0
#
# Chi-Square Test for native-country_Cambodia:
# Chi2=1.0670007181376575, p-value=0.30162389655688215
#
# Chi-Square Test for native-country_Canada:
# Chi2=3.9769339734684515, p-value=0.04612745417491731
#
# Chi-Square Test for native-country_China:
# Chi2=0.15142873222318146, p-value=0.6971737326575991
#
# Chi-Square Test for native-country_Columbia:
# Chi2=12.730899678626377, p-value=0.0003596634848422924
#
# Chi-Square Test for native-country_Cuba:
# Chi2=0.15212731149723044, p-value=0.6965106564295194
#
# Chi-Square Test for native-country_Dominican-Republic:
# Chi2=16.14059502412055, p-value=5.880986817222939e-05
#
# Chi-Square Test for native-country_Ecuador:
# Chi2=0.9833790662839511, p-value=0.3213659905836226
#
# Chi-Square Test for native-country_El-Salvador:
# Chi2=13.296151358159495, p-value=0.0002659514766247647
#
# Chi-Square Test for native-country_England:
# Chi2=3.7337161164412116, p-value=0.0533246326176449
#
# Chi-Square Test for native-country_France:
# Chi2=3.850994882819804, p-value=0.04971649230593712
#
# Chi-Square Test for native-country_Germany:
# Chi2=4.428089594787176, p-value=0.03535205604774742
#
# Chi-Square Test for native-country_Greece:
# Chi2=0.05036670864606848, p-value=0.822426397668016
#
# Chi-Square Test for native-country_Guatemala:
# Chi2=12.15082246875485, p-value=0.0004906622206938855
#
# Chi-Square Test for native-country_Haiti:
# Chi2=4.625364693040128, p-value=0.03150256357535856
#
# Chi-Square Test for native-country_Holand-Netherlands:
# Chi2=0.0, p-value=1.0
#
# Chi-Square Test for native-country_Honduras:
# Chi2=1.119077453078381, p-value=0.2901171888897116
#
# Chi-Square Test for native-country_Hong:
# Chi2=0.1279622382396262, p-value=0.7205542872731217
#
# Chi-Square Test for native-country_Hungary:
# Chi2=0.0, p-value=1.0
#
# Chi-Square Test for native-country_India:
# Chi2=13.044465780987373, p-value=0.0003041819122605274
#
# Chi-Square Test for native-country_Iran:
# Chi2=6.502920517749964, p-value=0.010769744481965427
#
# Chi-Square Test for native-country_Ireland:
# Chi2=0.017808554259122825, p-value=0.8938385365331702
#
# Chi-Square Test for native-country_Italy:
# Chi2=3.597103084170341, p-value=0.05788034932612638
#
# Chi-Square Test for native-country_Jamaica:
# Chi2=5.490287113566733, p-value=0.01912240251265363
#
# Chi-Square Test for native-country_Japan:
# Chi2=6.491629457506875, p-value=0.01083835877996352
#
# Chi-Square Test for native-country_Laos:
# Chi2=1.0233229852720653, p-value=0.31173208243645933
#
# Chi-Square Test for native-country_Mexico:
# Chi2=127.77283322526202, p-value=1.2585419846911276e-29
#
# Chi-Square Test for native-country_Nicaragua:
# Chi2=5.209511319532806, p-value=0.022463647807861576
#
# Chi-Square Test for native-country_Outlying-US(Guam-USVI-etc):
# Chi2=3.222564739783703, p-value=0.0726297502727671
#
# Chi-Square Test for native-country_Peru:
# Chi2=4.3539443579549975, p-value=0.0369233361485613
#
# Chi-Square Test for native-country_Philippines:
# Chi2=4.567889190811038, p-value=0.0325766813959912
#
# Chi-Square Test for native-country_Poland:
# Chi2=0.3467838539496446, p-value=0.5559393829468162
#
# Chi-Square Test for native-country_Portugal:
# Chi2=2.878297305778941, p-value=0.08978091069488728
#
# Chi-Square Test for native-country_Puerto-Rico:
# Chi2=10.76488214499107, p-value=0.0010344415141848686
#
# Chi-Square Test for native-country_Scotland:
# Chi2=0.0, p-value=1.0
#
# Chi-Square Test for native-country_South:
# Chi2=0.5239263281914508, p-value=0.4691716108146874
#
# Chi-Square Test for native-country_Taiwan:
# Chi2=5.597648663076755, p-value=0.01798459919148414
#
# Chi-Square Test for native-country_Thailand:
# Chi2=0.21177312569528844, p-value=0.6453811819375859
#
# Chi-Square Test for native-country_Trinadad&Tobago:
# Chi2=1.2407130819523677, p-value=0.26533366979414785
#
# Chi-Square Test for native-country_United-States:
# Chi2=49.0543873904587, p-value=2.4896273714267594e-12
#
# Chi-Square Test for native-country_Vietnam:
# Chi2=9.251416796174382, p-value=0.00235313302439516
#
# Chi-Square Test for native-country_Yugoslavia:
# Chi2=0.9278570061341131, p-value=0.3354204005018144

# %% [markdown]
# The Chi-Square test is a statistical hypothesis test that assumes (the null hypothesis) that the observed frequencies for a categorical variable match the expected frequencies for the categorical variable. The results include a Chi2 value and a p-value.
#
# For each categorical variable (after one-hot encoding), we performed a Chi-Square test with respect to the target variable 'income'. The Chi2 value indicates how much the observed frequencies deviate from the expected frequencies, while the p-value tells us about the statistical significance of our test.
#
# A small p-value (typically ≤ 0.05) indicates strong evidence that the observed frequency is different from the expected frequency, which means the variable likely has a significant relationship with the target variable.
#
# On the other hand, a large p-value (> 0.05) indicates weak evidence against the null hypothesis, so you fail to reject the null hypothesis. This means the variable likely does not have a significant relationship with the target variable.

# %% [markdown]
# ## ANOVA for Numerical Variables
#
# Analysis of Variance (ANOVA) is a statistical technique used to identify differences between two or more groups. In our case, we would like to identify if there are significant differences among groups of different income levels.
#
# The null hypothesis for ANOVA is that there is no difference in means among the groups. If the p-value is less than our chosen significance level (commonly 0.05), we reject the null hypothesis and conclude that there is a statistically significant difference in means among the groups.

# %%
# Perform ANOVA tests
for var in numerical_vars:
    group1 = df[df['income'] == '<=50K'][var]
    group2 = df[df['income'] == '>50K'][var]
    f_stat, p_val = stats.f_oneway(group1, group2)

    print(f'ANOVA Test for {var}:\nF-Statistic={f_stat}, p-value={p_val}\n')
# Out:
# ANOVA Test for age:
# F-Statistic=1886.7073137161226, p-value=0.0
#
# ANOVA Test for fnlwgt:
# F-Statistic=2.915593585649569, p-value=0.08773666108287717
#
# ANOVA Test for education-num:
# F-Statistic=4120.095779707457, p-value=0.0
#
# ANOVA Test for capital-gain:
# F-Statistic=1709.1500637437944, p-value=0.0
#
# ANOVA Test for capital-loss:
# F-Statistic=754.8304515515161, p-value=2.6865471891129668e-164
#
# ANOVA Test for hours-per-week:
# F-Statistic=1813.3862822161345, p-value=0.0

# %% [markdown]
# From the ANOVA tests, we observe that the p-values for most of our numerical variables are less than our chosen significance level of 0.05. Hence, we reject the null hypothesis that there is no difference in means among the income groups for these variables.
#
# This means that there are statistically significant differences in the means of these numerical variables among income groups. This is valuable information because it tells us that these numerical variables may be good predictors of income.
#
# However, there are also some variables that have p-values greater than 0.05, which suggests that the means of these variables do not significantly differ among income groups. We fail to reject the null hypothesis for these variables, implying that they may not be as effective predictors for income.

# %% [markdown]
# ## Effect Size Analysis
#
# Effect size is a quantitative measure of the magnitude of the experimenter effect. The larger the effect size, the stronger the relationship between two variables. We will calculate the Cohen's d, which is an appropriate effect size measure for t-tests.
#
# ## Point Biserial and Spearman Rank Correlation
#
# Afterwards, we will calculate Point Biserial Correlation for the relationship between our numerical variables and binary target variable. The Point-Biserial Correlation Coefficient is a correlation measure of the strength of association between a continuous-level variable (ratio or interval data) and a binary variable.
#
# For the categorical variables, we will calculate the Spearman Rank Correlation. The Spearman rank-order correlation coefficient is a nonparametric measure of the monotonicity of the relationship between two datasets. Unlike the Pearson correlation, the Spearman correlation does not assume that both datasets are normally distributed.

# %%
# Effect size (Cohen's d) calculation
for var in numerical_vars:
    group1 = df[df['income'] == '<=50K'][var]
    group2 = df[df['income'] == '>50K'][var]
    diff = group1.mean() - group2.mean()
    n1, n2 = len(group1), len(group2)
    var1 = group1.var()
    var2 = group2.var()
    pooled_var = (n1 * var1 + n2 * var2) / (n1 + n2)
    d = diff / np.sqrt(pooled_var)

    print(f'Effect Size for {var} (Cohen\'s d) = {d}\n')

# Replace 'income' values to binary
df['income_binary'] = df['income'].apply(lambda x: 1 if x == '>50K' else 0)

# Point Biserial Correlation
for var in numerical_vars:
    pbc = stats.pointbiserialr(df[var], df['income_binary'])
    print(f'Point Biserial Correlation for {var} = {pbc}\n')

# Spearman Rank Correlation
for var in categorical_cols:
    src = stats.spearmanr(df[var], df['income'])
    print(f'Spearman Rank Correlation for {var} = {src}\n')
# Out:
# Effect Size for age (Cohen's d) = -0.5629798646917087
#
# Effect Size for fnlwgt (Cohen's d) = 0.022131082425593883
#
# Effect Size for education-num (Cohen's d) = -0.8319413447327589
#
# Effect Size for capital-gain (Cohen's d) = -0.5358150457262507
#
# Effect Size for capital-loss (Cohen's d) = -0.3560885359154622
#
# Effect Size for hours-per-week (Cohen's d) = -0.5519310152474285
#
# Point Biserial Correlation for age = PointbiserialrResult(correlation=0.23403710264886493, pvalue=0.0)
#
# Point Biserial Correlation for fnlwgt = PointbiserialrResult(correlation=-0.009462557247529655, pvalue=0.08773666108238265)
#
# Point Biserial Correlation for education-num = PointbiserialrResult(correlation=0.3351539526909648, pvalue=0.0)
#
# Point Biserial Correlation for capital-gain = PointbiserialrResult(correlation=0.22332881819540146, pvalue=0.0)
#
# Point Biserial Correlation for capital-loss = PointbiserialrResult(correlation=0.15052631177034784, pvalue=2.6865471891972592e-164)
#
# Point Biserial Correlation for hours-per-week = PointbiserialrResult(correlation=0.22968906567081987, pvalue=0.0)
#
# Spearman Rank Correlation for workclass_Federal-gov = SpearmanrResult(correlation=0.059371745431794694, pvalue=7.983242072056612e-27)
#
# Spearman Rank Correlation for workclass_Local-gov = SpearmanrResult(correlation=0.03309057154415487, pvalue=2.3366001455910674e-09)
#
# Spearman Rank Correlation for workclass_Never-worked = SpearmanrResult(correlation=-0.00825863617457707, pvalue=0.13616861252524365)
#
# Spearman Rank Correlation for workclass_Private = SpearmanrResult(correlation=-0.12557318638000298, pvalue=1.4853438785092042e-114)
#
# Spearman Rank Correlation for workclass_Self-emp-inc = SpearmanrResult(correlation=0.13946655734053837, pvalue=4.222028486708984e-141)
#
# Spearman Rank Correlation for workclass_Self-emp-not-inc = SpearmanrResult(correlation=0.03001905396192195, pvalue=6.03195832242642e-08)
#
# Spearman Rank Correlation for workclass_State-gov = SpearmanrResult(correlation=0.014843290616542562, pvalue=0.0073960008388614835)
#
# Spearman Rank Correlation for workclass_Without-pay = SpearmanrResult(correlation=-0.011680731190582952, pvalue=0.03505348493916412)
#
# Spearman Rank Correlation for education_10th = SpearmanrResult(correlation=-0.07003784087284505, pvalue=1.0747892226095996e-36)
#
# Spearman Rank Correlation for education_11th = SpearmanrResult(correlation=-0.0858639232783975, pvalue=2.465032695337946e-54)
#
# Spearman Rank Correlation for education_12th = SpearmanrResult(correlation=-0.0446901713541708, pvalue=7.150960856674681e-16)
#
# Spearman Rank Correlation for education_1st-4th = SpearmanrResult(correlation=-0.03454398828995241, pvalue=4.518676596121856e-10)
#
# Spearman Rank Correlation for education_5th-6th = SpearmanrResult(correlation=-0.045826166824016114, pvalue=1.3040208698608764e-16)
#
# Spearman Rank Correlation for education_7th-8th = SpearmanrResult(correlation=-0.05952409498375852, pvalue=5.923315400424692e-27)
#
# Spearman Rank Correlation for education_9th = SpearmanrResult(correlation=-0.05576743851107198, pvalue=7.459855286529925e-24)
#
# Spearman Rank Correlation for education_Assoc-acdm = SpearmanrResult(correlation=0.0032502892468218624, pvalue=0.5575510510613643)
#
# Spearman Rank Correlation for education_Assoc-voc = SpearmanrResult(correlation=0.01004778008132036, pvalue=0.06982185919990899)
#
# Spearman Rank Correlation for education_Bachelors = SpearmanrResult(correlation=0.18048542920208185, pvalue=1.7610480780007903e-236)
#
# Spearman Rank Correlation for education_Doctorate = SpearmanrResult(correlation=0.13257200580963724, pvalue=1.4393157284211823e-127)
#
# Spearman Rank Correlation for education_HS-grad = SpearmanrResult(correlation=-0.13118854401281282, pvalue=6.141285401490978e-125)
#
# Spearman Rank Correlation for education_Masters = SpearmanrResult(correlation=0.17456971065152718, pvalue=3.9235809289031527e-221)
#
# Spearman Rank Correlation for education_Preschool = SpearmanrResult(correlation=-0.022306842300559016, pvalue=5.684430888574426e-05)
#
# Spearman Rank Correlation for education_Prof-school = SpearmanrResult(correlation=0.15490683578936076, pvalue=5.386996188250845e-174)
#
# Spearman Rank Correlation for education_Some-college = SpearmanrResult(correlation=-0.06353525542940647, pvalue=1.7439442147049465e-30)
#
# Spearman Rank Correlation for marital-status_Divorced = SpearmanrResult(correlation=-0.12699499612587498, pvalue=3.862864466892313e-117)
#
# Spearman Rank Correlation for marital-status_Married-AF-spouse = SpearmanrResult(correlation=0.012061398380602356, pvalue=0.029522767402259814)
#
# Spearman Rank Correlation for marital-status_Married-civ-spouse = SpearmanrResult(correlation=0.4446961550463166, pvalue=0.0)
#
# Spearman Rank Correlation for marital-status_Married-spouse-absent = SpearmanrResult(correlation=-0.042531557001367265, pvalue=1.6177174969215048e-14)
#
# Spearman Rank Correlation for marital-status_Never-married = SpearmanrResult(correlation=-0.31844032507377573, pvalue=0.0)
#
# Spearman Rank Correlation for marital-status_Separated = SpearmanrResult(correlation=-0.07438622703108844, pvalue=3.4838895736363385e-41)
#
# Spearman Rank Correlation for marital-status_Widowed = SpearmanrResult(correlation=-0.06438127591306408, pvalue=2.934960048706866e-31)
#
# Spearman Rank Correlation for occupation_Adm-clerical = SpearmanrResult(correlation=-0.08998555784163882, pvalue=1.61197041427069e-59)
#
# Spearman Rank Correlation for occupation_Armed-Forces = SpearmanrResult(correlation=-0.005043766399288652, pvalue=0.3627688838298492)
#
# Spearman Rank Correlation for occupation_Craft-repair = SpearmanrResult(correlation=-0.012575653760998323, pvalue=0.023253891476670455)
#
# Spearman Rank Correlation for occupation_Exec-managerial = SpearmanrResult(correlation=0.21486131464645092, pvalue=0.0)
#
# Spearman Rank Correlation for occupation_Farming-fishing = SpearmanrResult(correlation=-0.05192482646194626, pvalue=6.87659393015159e-21)
#
# Spearman Rank Correlation for occupation_Handlers-cleaners = SpearmanrResult(correlation=-0.08726514883228555, pvalue=4.536736961018083e-56)
#
# Spearman Rank Correlation for occupation_Machine-op-inspct = SpearmanrResult(correlation=-0.06940051324441952, pvalue=4.641074247066343e-36)
#
# Spearman Rank Correlation for occupation_Other-service = SpearmanrResult(correlation=-0.15634773905628313, pvalue=3.0045431824750546e-177)
#
# Spearman Rank Correlation for occupation_Priv-house-serv = SpearmanrResult(correlation=-0.037121538844057916, pvalue=2.0769322088681387e-11)
#
# Spearman Rank Correlation for occupation_Prof-specialty = SpearmanrResult(correlation=0.11299337481771038, pvalue=5.5314929598391795e-93)
#
# Spearman Rank Correlation for occupation_Protective-serv = SpearmanrResult(correlation=0.02811846577385907, pvalue=3.881241992321826e-07)
#
# Spearman Rank Correlation for occupation_Sales = SpearmanrResult(correlation=0.023688168354985464, pvalue=1.9123448006221344e-05)
#
# Spearman Rank Correlation for occupation_Tech-support = SpearmanrResult(correlation=0.02569627773966356, pvalue=3.5282713573189527e-06)
#
# Spearman Rank Correlation for occupation_Transport-moving = SpearmanrResult(correlation=-0.02147616988217003, pvalue=0.0001063616459754471)
#
# Spearman Rank Correlation for relationship_Husband = SpearmanrResult(correlation=0.40103526357745706, pvalue=0.0)
#
# Spearman Rank Correlation for relationship_Not-in-family = SpearmanrResult(correlation=-0.18849737130400468, pvalue=3.8813062386110937e-258)
#
# Spearman Rank Correlation for relationship_Other-relative = SpearmanrResult(correlation=-0.08371649655546802, pvalue=9.90911531788527e-52)
#
# Spearman Rank Correlation for relationship_Own-child = SpearmanrResult(correlation=-0.22853196347382307, pvalue=0.0)
#
# Spearman Rank Correlation for relationship_Unmarried = SpearmanrResult(correlation=-0.14285726137194357, pvalue=5.122189528664548e-148)
#
# Spearman Rank Correlation for relationship_Wife = SpearmanrResult(correlation=0.12326353972805605, pvalue=2.0282138159145574e-110)
#
# Spearman Rank Correlation for race_Amer-Indian-Eskimo = SpearmanrResult(correlation=-0.028721059409017233, pvalue=2.1777221945180176e-07)
#
# Spearman Rank Correlation for race_Asian-Pac-Islander = SpearmanrResult(correlation=0.010543232871476144, pvalue=0.057109596665149205)
#
# Spearman Rank Correlation for race_Black = SpearmanrResult(correlation=-0.08908860332216585, pvalue=2.2722786982310917e-58)
#
# Spearman Rank Correlation for race_Other = SpearmanrResult(correlation=-0.03182997497889279, pvalue=9.200361732703051e-09)
#
# Spearman Rank Correlation for race_White = SpearmanrResult(correlation=0.08522449750188024, pvalue=1.4934854798736003e-53)
#
# Spearman Rank Correlation for sex_Female = SpearmanrResult(correlation=-0.21598015058403636, pvalue=0.0)
#
# Spearman Rank Correlation for sex_Male = SpearmanrResult(correlation=0.21598015058403636, pvalue=0.0)
#
# Spearman Rank Correlation for native-country_Cambodia = SpearmanrResult(correlation=0.0072116103186250025, pvalue=0.19316330975895746)
#
# Spearman Rank Correlation for native-country_Canada = SpearmanrResult(correlation=0.011641838819113008, pvalue=0.0356654156683688)
#
# Spearman Rank Correlation for native-country_China = SpearmanrResult(correlation=0.0029056965367596542, pvalue=0.6000669509691565)
#
# Spearman Rank Correlation for native-country_Columbia = SpearmanrResult(correlation=-0.02061782486916454, pvalue=0.0001986945972214268)
#
# Spearman Rank Correlation for native-country_Cuba = SpearmanrResult(correlation=0.002827355393405611, pvalue=0.6099335631877405)
#
# Spearman Rank Correlation for native-country_Dominican-Republic = SpearmanrResult(correlation=-0.02303979779571485, pvalue=3.2126105609566736e-05)
#
# Spearman Rank Correlation for native-country_Ecuador = SpearmanrResult(correlation=-0.006720783095393673, pvalue=0.22524069489515638)
#
# Spearman Rank Correlation for native-country_El-Salvador = SpearmanrResult(correlation=-0.020838040188020535, pvalue=0.00016962910661228494)
#
# Spearman Rank Correlation for native-country_England = SpearmanrResult(correlation=0.011392382159462582, pvalue=0.03981094179947917)
#
# Spearman Rank Correlation for native-country_France = SpearmanrResult(correlation=0.012079144781718917, pvalue=0.02928436054085836)
#
# Spearman Rank Correlation for native-country_Germany = SpearmanrResult(correlation=0.012216467450178015, pvalue=0.027494927905262864)
#
# Spearman Rank Correlation for native-country_Greece = SpearmanrResult(correlation=0.00244765685171764, pvalue=0.6587387119952771)
#
# Spearman Rank Correlation for native-country_Guatemala = SpearmanrResult(correlation=-0.0201284961745, pvalue=0.0002808533698913607)
#
# Spearman Rank Correlation for native-country_Haiti = SpearmanrResult(correlation=-0.012896203018838672, pvalue=0.019960779562736272)
#
# Spearman Rank Correlation for native-country_Holand-Netherlands = SpearmanrResult(correlation=-0.0031211834514198625, pvalue=0.573307619495718)
#
# Spearman Rank Correlation for native-country_Honduras = SpearmanrResult(correlation=-0.007660205586126847, pvalue=0.16690238478958336)
#
# Spearman Rank Correlation for native-country_Hong = SpearmanrResult(correlation=0.0034319338765778015, pvalue=0.5357456955643825)
#
# Spearman Rank Correlation for native-country_Hungary = SpearmanrResult(correlation=-0.00046929414952775046, pvalue=0.9325163377200867)
#
# Spearman Rank Correlation for native-country_India = SpearmanrResult(correlation=0.020664448393075366, pvalue=0.0001921756704824069)
#
# Spearman Rank Correlation for native-country_Iran = SpearmanrResult(correlation=0.015120977284010564, pvalue=0.0063607428377067165)
#
# Spearman Rank Correlation for native-country_Ireland = SpearmanrResult(correlation=-0.002062861977655841, pvalue=0.7097270639752928)
#
# Spearman Rank Correlation for native-country_Italy = SpearmanrResult(correlation=0.011269939123851425, pvalue=0.04199098645620332)
#
# Spearman Rank Correlation for native-country_Jamaica = SpearmanrResult(correlation=-0.013706154044160706, pvalue=0.013389005379229737)
#
# Spearman Rank Correlation for native-country_Japan = SpearmanrResult(correlation=0.014943591843538166, pvalue=0.0070058009920307964)
#
# Spearman Rank Correlation for native-country_Laos = SpearmanrResult(correlation=-0.007133949115141792, pvalue=0.19800217993240593)
#
# Spearman Rank Correlation for native-country_Mexico = SpearmanrResult(correlation=-0.06290081708896135, pvalue=6.534861316006708e-30)
#
# Spearman Rank Correlation for native-country_Nicaragua = SpearmanrResult(correlation=-0.013760787051014575, pvalue=0.013024071497916307)
#
# Spearman Rank Correlation for native-country_Outlying-US(Guam-USVI-etc) = SpearmanrResult(correlation=-0.011680731190582952, pvalue=0.03505348493916412)
#
# Spearman Rank Correlation for native-country_Peru = SpearmanrResult(correlation=-0.012728074630027099, pvalue=0.02163340578815427)
#
# Spearman Rank Correlation for native-country_Philippines = SpearmanrResult(correlation=0.012306242941028138, pvalue=0.02637675319094802)
#
# Spearman Rank Correlation for native-country_Poland = SpearmanrResult(correlation=-0.0041008786923419, pvalue=0.45932147535008794)
#
# Spearman Rank Correlation for native-country_Portugal = SpearmanrResult(correlation=-0.01046796654910537, pvalue=0.058906714941662545)
#
# Spearman Rank Correlation for native-country_Puerto-Rico = SpearmanrResult(correlation=-0.01879061141577485, pvalue=0.0006967053010424025)
#
# Spearman Rank Correlation for native-country_Scotland = SpearmanrResult(correlation=0.0004127109548695682, pvalue=0.9406368404022629)
#
# Spearman Rank Correlation for native-country_South = SpearmanrResult(correlation=-0.004736744473149351, pvalue=0.3927162878806464)
#
# Spearman Rank Correlation for native-country_Taiwan = SpearmanrResult(correlation=0.014019711292720258, pvalue=0.01141154007925551)
#
# Spearman Rank Correlation for native-country_Thailand = SpearmanrResult(correlation=-0.004078164581120903, pvalue=0.46181223896868984)
#
# Spearman Rank Correlation for native-country_Trinadad&Tobago = SpearmanrResult(correlation=-0.007660029468624118, pvalue=0.16691213992207207)
#
# Spearman Rank Correlation for native-country_United-States = SpearmanrResult(correlation=0.038942084636251005, pvalue=2.0747436039639292e-12)
#
# Spearman Rank Correlation for native-country_Vietnam = SpearmanrResult(correlation=-0.017648564101987944, pvalue=0.0014487893829643879)
#
# Spearman Rank Correlation for native-country_Yugoslavia = SpearmanrResult(correlation=0.006958685561912739, pvalue=0.20924702296431283)

# %% [markdown]
# The effect size (Cohen's d) is a measure of the magnitude of the difference between two groups. Here, we use it to quantify the difference in means of our numerical variables between the two income groups. Generally, an absolute value of d=0.2 is considered a 'small' effect size, 0.5 represents a 'medium' effect size, and 0.8 a 'large' effect size. The results show that all the numerical variables have a small to medium effect size, implying there is a small to medium difference in means between the two income groups for these variables.
#
# The Point Biserial Correlation measures the strength and direction of the association that exists between one continuous variable and one dichotomous variable. In our case, the continuous variables are the numerical variables, and the dichotomous variable is the income group. All the numerical variables show a significant correlation with the income group, indicating that these variables could be good predictors of income.
#
# Spearman's Rank Correlation is used to examine the strength and direction of association between two ranked variables. In our case, these are the categorical variables. All the categorical variables show a significant correlation with the income group. This suggests that these variables might have an association with income and could be useful for our prediction model.
#
# However, as with the other tests, it's important to note that a statistically significant correlation doesn't guarantee a practically significant or useful feature. Further feature selection and engineering will be necessary to build a good prediction model.

# %% [markdown]
# ## General Summary
# In this notebook, we conducted a thorough statistical analysis of the variables in our dataset to understand which ones significantly influence income. We started with hypothesis testing for numerical variables using t-tests, then proceeded to hypothesis testing for categorical variables using chi-square tests. We also explored the correlation between numerical variables using Spearman correlation analysis. Subsequently, we ran a logistic regression analysis to evaluate the impact of different variables on the target variable. Our results provide valuable insights into the structure of the dataset and the relationships between different variables. The findings from this notebook will be instrumental in the upcoming feature selection and model building stages.
#
# ## Business Summary
# Our statistical analysis confirmed several intuitive assumptions about factors influencing income. The level of education, age, and hours per week worked significantly affect a person's income. This information will help us create a more accurate prediction model in the next stages. Additionally, it gives us a better understanding of the demographic and socioeconomic factors that impact income, which could be crucial for decision-makers.
